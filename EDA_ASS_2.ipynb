# %% [markdown]
# <a href="https://colab.research.google.com/github/geetha2612/Exploratory_Data_Analysis/blob/main/EDA_ASS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing Libraries
import pandas as pd
import numpy as np

# %%
#read data using read_csv () function
df=pd.read_csv('/content/basic2.csv')

# %%
#displaying the data frame
df
# Out:
#            Date     Sales      PV      UV  Events
# 0    2022-01-01  22711525  397349  4421.0       1
# 1    2022-01-02     36779    3969  2289.0       0
# 2    2022-01-03  13943875  373890     NaN       1
# 3    2022-01-04   8088593  142054  2157.0       0
# 4    2022-01-05   2395374  190684     NaN       0
# ..          ...       ...     ...     ...     ...
# 725  2023-12-27  33846609  415067  7360.0       1
# 726  2023-12-28   3659566  208601  2262.0       1
# 727  2023-12-29   1164008   14309   193.0       0
# 728  2023-12-30   3977696   60935     NaN       0
# 729  2023-12-31   3719764   60963  1507.0       0
#
# [730 rows x 5 columns]

# %%
df.head()
# Out:
#          Date     Sales      PV      UV  Events
# 0  2022-01-01  22711525  397349  4421.0       1
# 1  2022-01-02     36779    3969  2289.0       0
# 2  2022-01-03  13943875  373890     NaN       1
# 3  2022-01-04   8088593  142054  2157.0       0
# 4  2022-01-05   2395374  190684     NaN       0

# %%
#finding the data types of variables
df.dtypes
# Out:
# Date       object
# Sales       int64
# PV          int64
# UV        float64
# Events      int64
# dtype: object

# %%
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline
#SEABORN
import seaborn as sns

# %%
plt.scatter(df.index,df['Sales'],c='Red')
plt.gray()

# %%
sns.scatterplot (x=df.index, y=df['PV'], hue=df['Sales'])

# %%
plt.figure (figsize=(6,6))
plt.title('Line plot of Sales')
plt.xlabel('index', fontsize=20)
plt.ylabel('Sales', fontsize=20)
plt.plot(df.index, df ['Events'], markevery=1, marker='d')
for name, group in df.groupby('Events'):
    plt.plot(group.index, group['Sales'], label=name, markevery=1,marker='d')
plt.legend()
plt.show()

# %%
sns.set(rc={'figure.figsize': (7,7)})
sns.set (font_scale=1.5)

# %%
fig=sns.lineplot (x=df.index, y=df['Sales'], markevery=1, marker='d',data=df, hue=df ['Events'])
fig.set(xlabel='index')
# Out:
# [Text(0.5, 0, 'index')]

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df_placed = df.loc[df['Events']==1]
df_Notplaced = df.loc[df['Events']==0]

# %%
df_placed.head()
# Out:
#           Date     Sales      PV      UV  Events
# 0   2022-01-01  22711525  397349  4421.0       1
# 2   2022-01-03  13943875  373890     NaN       1
# 5   2022-01-06   1709350  177815  5340.0       1
# 21  2022-01-22  11732856  349679  4196.0       1
# 24  2022-01-25  24239428  294608     NaN       1

# %%
df_Notplaced.head()
# Out:
#          Date    Sales      PV      UV  Events
# 1  2022-01-02    36779    3969  2289.0       0
# 3  2022-01-04  8088593  142054  2157.0       0
# 4  2022-01-05  2395374  190684     NaN       0
# 6  2022-01-07  5306457  155749  3789.0       0
# 7  2022-01-08  1052325   53467  1793.0       0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(df_placed['UV'],np.zeros_like(df_placed['Sales']),'*')
plt.plot(df_Notplaced['UV'],np.zeros_like(df_Notplaced['Sales']),'o')

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
import seaborn as sns

# %%
df.isna().sum()
# Out:
# Date       0
# Sales      0
# PV         0
# UV        46
# Events     0
# dtype: int64

# %%
drop = df.dropna()

# %%
drop.isna().sum()
# Out:
# Date      0
# Sales     0
# PV        0
# UV        0
# Events    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
plt.title('Sales vs PV(r = {0:0.2f})'.format(pearsonr(drop['Sales'],drop['PV'])[0]))
sns.scatterplot(x="Sales",y="PV",data = df, hue='PV')

# %%
plt.title('UV vs Events(r = {0:0.2f})'.format(pearsonr(drop['UV'],drop['Events'])[0]))
sns.scatterplot(x="UV",y="Events",data = df, hue='Events')

# %%
plt.title('UV vs Sales(r = {0:0.2f})'.format(pearsonr(drop['UV'],drop['Sales'])[0]))
sns.scatterplot(x="UV", y="Sales",hue="Events", style="Events", data=df)
plt.show()

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(data=df[ ['Sales', 'PV', 'UV', 'Date', 'Events']], hue='Events')

# %%
sns.pairplot(df,hue ='PV',size = 2)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
