# %% [markdown]
# <a href="https://colab.research.google.com/github/geetha2612/Exploratory_Data_Analysis/blob/main/Eda_ex_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/gold.csv',parse_dates=True,index_col='Date')

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2000-01-04  289.5  289.5  280.0  283.7   21621      USD
# 2000-01-05  283.7  285.0  281.0  282.1   25448      USD
# 2000-01-06  281.6  282.8  280.2  282.4   19055      USD
# 2000-01-07  282.5  284.5  282.0  282.9   11266      USD
# 2000-01-10  282.4  283.9  281.8  282.7   30603      USD
# 2000-01-11  282.4  285.3  281.9  284.4   13500      USD
# 2000-01-12  284.5  285.0  282.5  283.7   17841      USD
# 2000-01-13  283.5  285.9  282.9  285.1   12171      USD
# 2000-01-14  285.2  285.6  284.0  284.9   32339      USD
# 2000-01-18  286.1  289.8  285.9  289.6   28615      USD

# %%
df.isna()
# Out:
#              Open   High    Low  Close  Volume  Currency
# Date
# 2000-01-04  False  False  False  False   False     False
# 2000-01-05  False  False  False  False   False     False
# 2000-01-06  False  False  False  False   False     False
# 2000-01-07  False  False  False  False   False     False
# 2000-01-10  False  False  False  False   False     False
# ...           ...    ...    ...    ...     ...       ...
# 2022-08-29  False  False  False  False   False     False
# 2022-08-30  False  False  False  False   False     False
# 2022-08-31  False  False  False  False   False     False
# 2022-09-01  False  False  False  False   False     False
# 2022-09-02  False  False  False  False   False     False
#
# [5703 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Open        0
# High        0
# Low         0
# Close       0
# Volume      0
# Currency    0
# dtype: int64

# %%
df['Volume'].plot()

# %%
df.plot(subplots=True, figsize=(10, 12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f56b4275fd0>,
# ...
#       dtype=object)

# %%
df_month = df.resample("M").mean()

# using subplot
fig, ax = plt.subplots(figsize=(10, 6))

# plotting bar graph
ax.bar(df_month['2016':].index,
       df_month.loc['2016':, "Volume"],
       width=25, align='center')
# Out:
# <BarContainer object of 81 artists>

# %%
df.Low.diff(2).plot(figsize=(10, 6))

# %%
df.High.diff(2).plot(figsize=(10, 6))
